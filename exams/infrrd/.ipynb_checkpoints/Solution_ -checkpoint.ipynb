# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

sns.set_style("darkgrid")

base_path = "/home/vishal/datasets/exams/Infrrd/"
train_path = base_path+"train.csv"
test_path =  base_path+"test.csv"

dataset = pd.read_csv(train_path)
dataset.head()
# Out:
#   purchasing_cost repair_cost windows people   space safety         label
# 0            high   very_high   5more   more  medium    med  unacceptable
# 1       very_high      medium       4   more     big    low  unacceptable
# 2          medium      medium   5more      4  medium    low  unacceptable
# 3            high        high       2   more  medium   high    acceptable
# 4            high   very_high   5more      2     big   high  unacceptable

# %%
# Exploratory Analysis

dataset.dtypes  # all are categorical feature
# Out:
# purchasing_cost    object
# repair_cost        object
# windows            object
# people             object
# space              object
# safety             object
# label              object
# dtype: object

# %%
dataset.describe() 
# No Null values
# Out:
#        purchasing_cost repair_cost windows people space safety         label
# count             1382        1382    1382   1382  1382   1382          1382
# unique               4           4       4      3     3      3             4
# top                low        high   5more      4   big    low  unacceptable
# freq               353         356     354    473   466    468           974

# %%
dataset['purchasing_cost'].value_counts(dropna = False)
dataset['purchasing_cost'].value_counts(dropna = False).head(10).plot.bar()

# %%
#dataset['repair_cost'].value_counts(dropna = False)
dataset['repair_cost'].value_counts(dropna = False).head(10).plot.bar()

# %%
#dataset['windows'].value_counts(dropna = False)
dataset['windows'].value_counts(dropna = False).plot.bar()

# %%
#dataset['people'].value_counts(dropna = False)
dataset['people'].value_counts(dropna = False).plot.bar()

# %%
dataset['space'].value_counts(dropna = False)
dataset['space'].value_counts(dropna = False).plot.bar()

# %%
dataset['safety'].value_counts(dropna = False)
#dataset['safety'].value_counts(dropna = False).plot.bar()
# Out:
# low     468
# high    457
# med     457
# Name: safety, dtype: int64

# %%
dataset['label'].value_counts(dropna = False) # Data is Not balanced
dataset['label'].value_counts(dropna = False).plot.bar()

# %%
# level encodeders

def label_encoder(val, col_dict):
    return col_dict[val]

pc_dict = {'low':1, 'medium':2, 'high': 3, 'very_high': 4}
dataset['pc'] = dataset['purchasing_cost'].apply(label_encoder, args = (pc_dict,))

rc_dict = {'low':1, 'medium':2, 'high': 3, 'very_high': 4}
dataset['rc'] = dataset['repair_cost'].apply(label_encoder, args = (rc_dict,))

windows_dict = {'2':2, '3':3, '4':4, '5more': 5}
dataset['win'] = dataset['windows'].apply(label_encoder, args = (windows_dict,))

people_dict = {'2':2, '4':4, 'more': 6}
dataset['ppl'] = dataset['people'].apply(label_encoder, args = (people_dict,))

space_dict = {'small':1, 'medium':2, 'big': 3}
dataset['spc'] = dataset['space'].apply(label_encoder, args = (space_dict,))

safety_dict = {'low':1, 'med':2, 'high': 3}
dataset['sfty'] = dataset['safety'].apply(label_encoder, args = (safety_dict,))

label_dict = {'unacceptable':1, 'acceptable':2, 'good': 3, 'very_good':4}
dataset['lbl'] = dataset['label'].apply(label_encoder, args = (label_dict,))

dataset.head()
# Out:
#   purchasing_cost repair_cost windows people   space safety         label  pc  \
# 0            high   very_high   5more   more  medium    med  unacceptable   3
# 1       very_high      medium       4   more     big    low  unacceptable   4
# 2          medium      medium   5more      4  medium    low  unacceptable   2
# 3            high        high       2   more  medium   high    acceptable   3
# 4            high   very_high   5more      2     big   high  unacceptable   3
#
#    rc  win  ppl  spc  sfty  lbl
# 0   4    5    6    2     2    1
# 1   2    4    6    3     1    1
# 2   2    5    4    2     1    1
# 3   3    2    6    2     3    2
# 4   4    5    2    3     3    1

# %%
# Correlation cofficient matrix 
data_vec = dataset[['pc', 'rc','win', 'ppl', 'spc','sfty','lbl']]
data_vec.corr(method= 'spearman')
# Out:
#             pc        rc       win       ppl       spc      sfty       lbl
# pc    1.000000  0.009392 -0.014983  0.002779  0.003906 -0.008405 -0.238156
# rc    0.009392  1.000000  0.007743 -0.000593  0.000871  0.003533 -0.197291
# win  -0.014983  0.007743  1.000000 -0.001046  0.025910  0.011653  0.070634
# ppl   0.002779 -0.000593 -0.001046  1.000000  0.030665 -0.023079  0.393119
# spc   0.003906  0.000871  0.025910  0.030665  1.000000  0.007663  0.141323
# sfty -0.008405  0.003533  0.011653 -0.023079  0.007663  1.000000  0.469193
# lbl  -0.238156 -0.197291  0.070634  0.393119  0.141323  0.469193  1.000000

# %%
# data selection round 1
from sklearn.model_selection import train_test_split
y = data_vec['lbl']
X  = data_vec[['win', 'ppl', 'spc', 'sfty']]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=1)

# %%
# Round 1 # Model 1
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(random_state=0)
clf.fit(X_train,y_train)
#clf.feature_importances_
#clf.score(X_train, y_train)
clf.score(X_test, y_test)
# Out:
# 0.8050541516245487

# %%
# Round 1 feature importance graph
y_pos = np.arange(len(X.columns))
feature_importance = clf.feature_importances_
plt.barh(y_pos, feature_importance, align='center', alpha=0.5)
plt.yticks(y_pos, X.columns)
plt.xlabel('importance')
# Out:
# Text(0.5,0,'importance')

# %%
# round 1 # model 2
from sklearn.svm import LinearSVC
clf_svm = LinearSVC(random_state=0)
clf_svm.fit(X_train, y_train)
clf_svm.score(X_train, y_train)
# Out:
# 0.7746606334841629

# %%
# round 1 model 3
from sklearn import svm
clf_mlticlass = svm.SVC(decision_function_shape='ovo')
clf_mlticlass.fit(X_train,y_train)
clf_mlticlass.score(X_train, y_train)
# Out:
# 0.8298642533936652

# %%
# Round 1  # Model overfitting test : Testing on test data
clf_mlticlass.score(X_test, y_test)
# Out:
# 0.8122743682310469

# %%
# New feature cration (Polynomialy feature creation)

# %%
dataset['win_ppl'] = dataset['win'] * dataset['ppl']
dataset['win_spc'] = dataset['win'] * dataset['spc']
dataset['win_sfty'] = dataset['win'] * dataset['sfty']

dataset['ppl_spc'] = dataset['ppl'] * dataset['spc']
dataset['ppl_sfty'] = dataset['ppl'] * dataset['sfty']

dataset['spc_sfty'] = dataset['spc'] * dataset['sfty']

dataset.head()
# Out:
#   purchasing_cost repair_cost windows people   space safety         label  pc  \
# 0            high   very_high   5more   more  medium    med  unacceptable   3
# 1       very_high      medium       4   more     big    low  unacceptable   4
# 2          medium      medium   5more      4  medium    low  unacceptable   2
# 3            high        high       2   more  medium   high    acceptable   3
# 4            high   very_high   5more      2     big   high  unacceptable   3
#
#    rc  win  ppl  spc  sfty  lbl  win_ppl  win_spc  win_sfty  ppl_spc  \
# 0   4    5    6    2     2    1       30       10        10       12
# 1   2    4    6    3     1    1       24       12         4       18
# 2   2    5    4    2     1    1       20       10         5        8
# 3   3    2    6    2     3    2       12        4         6       12
# 4   4    5    2    3     3    1       10       15        15        6
#
#    ppl_sfty  spc_sfty
# 0        12         4
# 1         6         3
# 2         4         2
# 3        18         6
# 4         6         9

# %%
# Round 2 Correlation cofficient matrix 
data_vec = dataset[['pc', 'rc','win', 'ppl', 'spc','sfty','win_ppl','win_spc','win_sfty','ppl_spc','ppl_sfty','spc_sfty','lbl']]
data_vec.corr(method= 'spearman')
# Out:
#                 pc        rc       win       ppl       spc      sfty  \
# pc        1.000000  0.009392 -0.014983  0.002779  0.003906 -0.008405
# rc        0.009392  1.000000  0.007743 -0.000593  0.000871  0.003533
# win      -0.014983  0.007743  1.000000 -0.001046  0.025910  0.011653
# ppl       0.002779 -0.000593 -0.001046  1.000000  0.030665 -0.023079
# spc       0.003906  0.000871  0.025910  0.030665  1.000000  0.007663
# sfty     -0.008405  0.003533  0.011653 -0.023079  0.007663  1.000000
# win_ppl  -0.009477  0.000343  0.575692  0.800171  0.039217 -0.013357
# win_spc  -0.004007  0.005702  0.585874  0.026028  0.808194  0.011083
# win_sfty -0.014894  0.010369  0.578519 -0.016364  0.020874  0.806328
# ppl_spc   0.004553  0.002857  0.013888  0.703323  0.706960 -0.012726
# ppl_sfty -0.001519  0.000670  0.005329  0.683001  0.025186  0.689362
# spc_sfty -0.004449  0.005197  0.021665  0.003434  0.695182  0.697589
# lbl      -0.238156 -0.197291  0.070634  0.393119  0.141323  0.469193
#
#            win_ppl   win_spc  win_sfty   ppl_spc  ppl_sfty  spc_sfty       lbl
# pc       -0.009477 -0.004007 -0.014894  0.004553 -0.001519 -0.004449 -0.238156
# rc        0.000343  0.005702  0.010369  0.002857  0.000670  0.005197 -0.197291
# win       0.575692  0.585874  0.578519  0.013888  0.005329  0.021665  0.070634
# ppl       0.800171  0.026028 -0.016364  0.703323  0.683001  0.003434  0.393119
# spc       0.039217  0.808194  0.020874  0.706960  0.025186  0.695182  0.141323
# sfty     -0.013357  0.011083  0.806328 -0.012726  0.689362  0.697589  0.469193
# win_ppl   1.000000  0.360997  0.320812  0.579614  0.556739  0.013768  0.383367
# win_spc   0.360997  1.000000  0.345079  0.579395  0.023270  0.571852  0.154044
# win_sfty  0.320812  0.345079  1.000000 -0.000553  0.564748  0.579652  0.433110
# ppl_spc   0.579614  0.579395 -0.000553  1.000000  0.490040  0.486235  0.397342
# ppl_sfty  0.556739  0.023270  0.564748  0.490040  1.000000  0.502475  0.672739
# spc_sfty  0.013768  0.571852  0.579652  0.486235  0.502475  1.000000  0.449363
# lbl       0.383367  0.154044  0.433110  0.397342  0.672739  0.449363  1.000000

# %%
y_2 = data_vec['lbl']
X_2  = data_vec[['win', 'ppl', 'spc', 'sfty', 'win_ppl', 'win_spc','win_sfty','ppl_spc', 'ppl_spc', 'ppl_sfty', 'spc_sfty']]
X_train_2, X_test_2, y_train_2, y_test_2 = train_test_split(X_2, y_2, test_size=0.20, random_state=1)

# %%
# ROund 2 model 1
from sklearn import svm
clf_mlticlass_2 = svm.SVC(decision_function_shape='ovo')
clf_mlticlass_2.fit(X_train_2,y_train_2)
clf_mlticlass_2.score(X_train_2, y_train_2)
# Out:
# 0.8343891402714932

# %%
# Remaning Study is: Data balasing [SMOTE], Model selection based f1 score etc

# %%
data_test = pd.read_csv(test_path)
data_test['win'] = data_test['windows'].apply(label_encoder, args= (windows_dict,))
data_test['ppl'] = data_test['people'].apply(label_encoder, args= (people_dict,))
data_test['spc'] = data_test['space'].apply(label_encoder, args= (space_dict,))
safety_dict['medium'] = 2
data_test['sfty'] = data_test['safety'].apply(label_encoder, args= (safety_dict,))
data_test.head()
# Out:
#   purchasing_cost repair_cost windows people   space safety  win  ppl  spc  \
# 0             low      medium       2      2  medium   high    2    2    2
# 1            high        high       4      2     big   high    4    2    3
# 2             low   very_high   5more      2   small    low    5    2    1
# 3            high   very_high   5more   more  medium    low    5    6    2
# 4          medium         low       4      4   small    low    4    4    1
#
#    sfty
# 0     3
# 1     3
# 2     1
# 3     1
# 4     1

# %%
data_test['win_ppl'] = data_test['win'] * data_test['ppl']
data_test['win_spc'] = data_test['win'] * data_test['spc']
data_test['win_sfty'] = data_test['win'] * data_test['sfty']

data_test['ppl_spc'] = data_test['ppl'] * data_test['spc']
data_test['ppl_sfty'] = data_test['ppl'] * data_test['sfty']

data_test['spc_sfty'] = data_test['spc'] * data_test['sfty']
data_test.head()
# Out:
#   purchasing_cost repair_cost windows people   space safety  win  ppl  spc  \
# 0             low      medium       2      2  medium   high    2    2    2
# 1            high        high       4      2     big   high    4    2    3
# 2             low   very_high   5more      2   small    low    5    2    1
# 3            high   very_high   5more   more  medium    low    5    6    2
# 4          medium         low       4      4   small    low    4    4    1
#
#    sfty  win_ppl  win_spc  win_sfty  ppl_spc  ppl_sfty  spc_sfty
# 0     3        4        4         6        4         6         6
# 1     3        8       12        12        6         6         9
# 2     1       10        5         5        2         2         1
# 3     1       30       10         5       12         6         2
# 4     1       16        4         4        4         4         1

# %%
X_test_2  = data_vec[['win', 'ppl', 'spc', 'sfty', 'win_ppl', 'win_spc','win_sfty','ppl_spc', 'ppl_spc', 'ppl_sfty', 'spc_sfty']]
X_test_2.head()
y_cap = clf_mlticlass_2.predict(X_test_2)
data_test['y']= pd.DataFrame(y_cap)

# %%
# inverse transformation of lebel

inv_label_dict = {1:'unacceptable', 2:'acceptable', 3:'good',4:'very_good'}
data_test['lbl_y'] = data_test['y'].apply(label_encoder, args= (inv_label_dict,))
final_data_set = data_test[['purchasing_cost','repair_cost','windows','people','space','safety','lbl_y']]
final_data_set.head()
# Out:
#   purchasing_cost repair_cost windows people   space safety         lbl_y
# 0             low      medium       2      2  medium   high    acceptable
# 1            high        high       4      2     big   high  unacceptable
# 2             low   very_high   5more      2   small    low  unacceptable
# 3            high   very_high   5more   more  medium    low    acceptable
# 4          medium         low       4      4   small    low  unacceptable
