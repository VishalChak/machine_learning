# %%
import tensorflow as tf
import keras as kr
import spacy

# %%
import pandas as pd

# %%
nlp = spacy.load('en')

# %%
doc = nlp("I am vishal chak")

# %%
for word in doc:
    print(word.text, word.pos_, word.tag_)
# Out:
# I PRON PRP
# am VERB VBP
# vishal ADJ JJ
# chak NOUN NN

# %%
doc.sentiment
# Out:
# 0.0

# %%
doc1 = nlp("vishal is a bad boy. He dont rispect to older")

# %%
doc1.sentiment
# Out:
# 0.0

# %%
for word in doc1.vector:
    print(word)
# Out:
# 0.53230566
# 0.13183855
# 0.6369209
# 2.0720263
# 0.5159947
# 0.077204265
# 0.08886027
# -0.023341784
# 0.99701434
# -0.1061218
# -0.2561129
# -0.42639506
# 0.53542167
# -0.7631747
# -0.2923268
# -0.44965458
# -0.6663108
# 0.6429852
# -0.4466528
# 0.13256697
# 0.2508368
# 0.44279745
# 0.03705625
# 0.2082632
# -0.886848
# -0.44885647
# -0.26039094
# 0.7485772
# -0.042660784
# -0.5332886
# -0.120111205
# 0.46240103
# 0.40107548
# -0.60534674
# 0.08567756
# -0.019114196
# -0.112484336
# 0.28201035
# 0.1358736
# -0.8212457
# -0.5137484
# 0.6158369
# 0.6884665
# -0.38733134
# -1.4479885
# 1.1659542
# 0.6872308
# -0.7420662
# 0.93619496
# 0.41891727
# -0.3038877
# -1.302724
# -0.5649098
# 0.07653866
# -0.1316988
# 0.35852394
# 0.5164985
# 0.99390954
# -1.1956139
# 0.38843104
# -0.23380573
# 0.18251543
# -0.5129488
# 0.3363391
# -0.2692357
# 1.193008
# -0.8256214
# 0.44047502
# 0.11108991
# 0.3404913
# -0.018755049
# -0.39665022
# -0.28159368
# -0.009509087
# -1.2586242
# -0.15681641
# ...

# %%
doc1.vector
# Out:
# array([ 5.32305658e-01,  1.31838545e-01,  6.36920929e-01,  2.07202625e+00,
#         5.15994728e-01,  7.72042647e-02,  8.88602734e-02, -2.33417843e-02,
#         9.97014344e-01, -1.06121801e-01, -2.56112903e-01, -4.26395059e-01,
#         5.35421669e-01, -7.63174713e-01, -2.92326808e-01, -4.49654579e-01,
#        -6.66310787e-01,  6.42985225e-01, -4.46652800e-01,  1.32566974e-01,
#         2.50836790e-01,  4.42797452e-01,  3.70562486e-02,  2.08263204e-01,
#        -8.86847973e-01, -4.48856473e-01, -2.60390937e-01,  7.48577178e-01,
#        -4.26607840e-02, -5.33288598e-01, -1.20111205e-01,  4.62401032e-01,
#         4.01075482e-01, -6.05346739e-01,  8.56775567e-02, -1.91141963e-02,
#        -1.12484336e-01,  2.82010347e-01,  1.35873601e-01, -8.21245670e-01,
#        -5.13748407e-01,  6.15836918e-01,  6.88466489e-01, -3.87331337e-01,
#        -1.44798851e+00,  1.16595423e+00,  6.87230825e-01, -7.42066205e-01,
# ...
